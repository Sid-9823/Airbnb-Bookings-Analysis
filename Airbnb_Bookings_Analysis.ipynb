# %% [markdown]
# <a href="https://colab.research.google.com/github/Sid-9823/Airbnb-Bookings-Analysis/blob/main/Airbnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  <u>**Project Title : Airbnb Bookings Analysis**</u>
#
# #####**Project Type** - EDA
#
# #####**Contribution** - Individual
#
# #####**Individual name** - Siddhant Pal
#
# #####**Cohort** - Berlin

# %% [markdown]
# ![airbnb.png](data:image/png;base64,...)

# %% [markdown]
# #**Project Summary**

# %% [markdown]
# #**GitHub Link**

# %% [markdown]
# https://github.com/Sid-9823/Airbnb-Bookings-Analysis

# %% [markdown]
# #**Problem statement**

# %% [markdown]
# ####**BUSINESS PROBLEM OVERVIEW**
#
# * **What is the number of Airbnb apartments in each neighbourhood group ?**
#
# * **How much does a unit cost on average in each neighbourhood group ?**
#
# * **What are the top ten neighbourhoods in terms of unit count ?**
#
# * **What are the top ten most affordable neighbourhoods ?**
#
# * **What are the top ten most expensive neighbourhoods ?**
#
# * **Which room type is most prevalent in each neighbourhood ?**
#
# * **Who are the top ten hosts in New York City ?**
#
# * **How does the price influence the unit's 365-day availability ?**
#
# * **What effect does pricing have on the amount of reviews ?**
#
# * **What is the bare minimum of nights that hosts prefer ?**

# %% [markdown]
# **Despite the fact that Airbnb does not own any real estate, it produced $8.4 billion in income in 2022. Now, they aim to join the hotel sector starting with their first hotel New York City under the brand name, 'Airbnb Stay'.**
#
# **As a result, we will do a complete Exploratory Data Analysis on current Airbnb units in order to give management with solutions that are both affordable and lucrative.**

# %% [markdown]
# ### **Data Description**
#
# **The dataset contains information such as id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, Number_of_reviews, last_review, reeviews_per_month, calculated_host_listing_count and availability_365.**
#
# **Feature's Information :**
# * ***id*** : *Unique ID.*
#
# * ***name*** : *Name of the listing.*
#
# * ***host_id*** : *Unique host_id.*
#
# * ***host_name*** : *Name of the host.*
#
# * ***neighbourhood_group*** : *location.*
#
# * ***neighbourhood*** : *Area*
#
# * ***latitude*** : *Latitude range.*
#
# * ***longitude*** : *Longitude range.*
#
# * ***room_type*** : *Type of listing.*
#
# * ***price*** : *Price of listing.*
#
# * ***minimum_nights*** : *Minimum nights to be paid for.*
#
# * ***number_of_reviews*** : *Number of reviews.*
#
# * ***last_review*** : *Content of the last review.*
#
# * ***reviews_per_month*** : *Number of checks per month.*
#
# * ***calculated_host_listings_count*** : *Total count.*
#
# * ***availability_365*** :  *Availability around the year.*

# %% [markdown]
# #**Importing necessary libraries**

# %%
# For plotting plots and graphs.

import matplotlib.pyplot as plt
import seaborn as sns

# For numerical python, calculation and data manipulation.

import numpy as np
import pandas as pd

# %% [markdown]
# # **Data collection and analysis**

# %% [markdown]
# ##**Data Loading and Basic Analysis**

# %%
# Loading the data from csv file to a pandas dataframe.

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Airbnb NYC 2019.csv')

# %%
# Printing first 5 rows.

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
 # Printing last 5 rows.

df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Checking the number of rows and columns in our dataset.

df.shape
# Out:
# (48895, 16)

# %%
# Gathering information about our dataset such as null count values and data types involved.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
#  Getting the statistical measure of the dataframe.

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Printing number of unique values in our dataset.

df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
# Checking null values.

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# * ***As we can see there are missing values in this dataframe***

# %% [markdown]
# ##**Data wrangling**

# %%
# Renaming our column's.

df = df.rename(columns={'host_id':'hid','host_name':'hname','neighbourhood_group':'ngrp','neighbourhood':'neigh','latitude':'lat','longitude':'long',
                        'room_type':'roomt','minimum_nights':'minn','number_of_reviews':'nor','last_review':'lstrvw','reviews_per_month':'rvwmnth','calculated_host_listings_count' : 'calchlc','availability_365' : 'a365'})

# %% [markdown]
# * ***Changing column's names as per our convenience as it becomes easier working with small feature names.***

# %%
df.head()
# Out:
#      id                                              name   hid        hname  \
# 0  2539                Clean & quiet apt home by the park  2787         John
# 1  2595                             Skylit Midtown Castle  2845     Jennifer
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !  4632    Elisabeth
# 3  3831                   Cozy Entire Floor of Brownstone  4869  LisaRoxanne
# 4  5022  Entire Apt: Spacious Studio/Loft by central park  7192        Laura
#
#         ngrp         neigh       lat      long            roomt  price  minn  \
# 0   Brooklyn    Kensington  40.64749 -73.97237     Private room    149     1
# 1  Manhattan       Midtown  40.75362 -73.98377  Entire home/apt    225     1
# 2  Manhattan        Harlem  40.80902 -73.94190     Private room    150     3
# 3   Brooklyn  Clinton Hill  40.68514 -73.95976  Entire home/apt     89     1
# 4  Manhattan   East Harlem  40.79851 -73.94399  Entire home/apt     80    10
#
# ...

# %% [markdown]
# * ***The column's name has been changed.***

# %%
# Handling Null values.

df['name'].fillna(df['roomt'], inplace = True)

df['hname'].fillna(df['roomt'], inplace = True)

# %% [markdown]
# * ***Replacing the null values of the 'name' and 'host_name' column with 'room_type' values.***

# %%
# Dropping columns.

df.drop(columns = ['lstrvw','rvwmnth'], axis = 1, inplace = True)

# %% [markdown]
# * ***Dropping columns 'last_review' and reviews_per_month as they consist of more than 20% missing values.***

# %%
df.describe()
# Out:
#                  id           hid           lat          long         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#                minn           nor       calchlc          a365
# count  48895.000000  48895.000000  48895.000000  48895.000000
# mean       7.029962     23.274466      7.143982    112.781327
# std       20.510550     44.550582     32.952519    131.622289
# ...

# %% [markdown]
# * ***We can see that the maximum value for the minimum number of nights to stay is 1250, which isn't possible as there are only 365 days in a year.***
#
# * ***In the price column, there are entries with 0, which isn't possible as a stay could not be free of charge.***

# %%
# Finding entries greater than 365.

df[df['minn'] > 365].shape[0]
# Out:
# 14

# %% [markdown]
# * ***There are 14 entries with values greater than 365.***

# %%
# Transforming entries.

df['minn'] = df['minn'].apply(lambda x : 365 if x > 365 else x)

# %% [markdown]
# * ***Replacing any values that are greater than 365 with 365.***

# %%
# Finding entries greater than 365.

df[df['minn'] > 365].shape[0]
# Out:
# 0

# %% [markdown]
# * ***Now there are no entries greater than 365.***

# %%
# Finding rows with 0 as value in price column.

df[df['price'] == 0]
# Out:
#              id                                               name        hid  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %% [markdown]
# * ***There are 11 entries with 0 as a value in the price column.***

# %%
# Using groupby to find average.

pd.DataFrame(df.groupby('ngrp')['price'].mean())
# Out:
#                     price
# ngrp
# Bronx           87.496792
# Brooklyn       124.383207
# Manhattan      196.875814
# Queens          99.517649
# Staten Island  114.812332

# %% [markdown]
# * ***Calculating the mean of the neighbourhood groups using groupby.***

# %%
df['price'][(df['ngrp'] == 'Bronx')     &  (df['price'] == 0)]   =  87.0

df['price'][(df['ngrp'] == 'Brooklyn')  &  (df['price'] == 0)]   =  124.0

df['price'][(df['ngrp'] == 'Manhattan') &  (df['price'] == 0)]   =  197.0
# Out:
# <ipython-input-53-ab4ce98c9178>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][(df['ngrp'] == 'Bronx')     &  (df['price'] == 0)]   =  87.0
# <ipython-input-53-ab4ce98c9178>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][(df['ngrp'] == 'Brooklyn')  &  (df['price'] == 0)]   =  124.0
# <ipython-input-53-ab4ce98c9178>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# * ***Replacing null values in the 'price' column with the mean value of that particular neighbourhood region.***

# %%
# Finding rows with 0 as value in price column.

df[df['price'] == 0].shape[0]
# Out:
# 0

# %% [markdown]
# * ***There are no entries with a value of 0 in the 'price' column.***

# %% [markdown]
# # **Exploratory Data Analysis and Visualization**

# %% [markdown]
# **What is EDA ?**
#
# ***Exploratory Data Analysis can be considered as a process which is used to visualise data and it helps to uncover the underlying pattern and relations between the dependent and independent variable's which can be useful in decision making.***

# %% [markdown]
# ##**What is the number of Airbnb apartments in each neighbourhood group ?**

# %%
# Plotting a barplot.

plt.figure(figsize=(10, 5))
ax = df.groupby('ngrp')['id'].count().plot(kind='bar', color='skyblue', edgecolor='black')

# To annotate the countplot.

for p in ax.patches:
  ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()),
  ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

plt.xlabel('Neighbourhood Groups', fontsize=14)
plt.title('Number of Airbnb apartments in different neighbourhood groups', fontsize=16, fontweight = 'bold')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %% [markdown]
# * ***Manhattan has the highest number of Airbnb apartments, followed by Brooklyn.***

# %% [markdown]
# ##**How much does a unit cost on average in each neighbourhood group ?**

# %%
# Create the figure and axis objects

plt.figure(figsize=(10, 5))
ax = df.groupby('ngrp')['price'].mean().plot(kind='bar', color='skyblue', edgecolor='black')

# To annotate the countplot.

for p in ax.patches:
  ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()),
  ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

plt.xlabel('Neighbourhood Groups', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Unit average cost in each neighbourhood group', fontsize=16, fontweight = 'bold')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %% [markdown]
# * ***Unit costs are highest in Manhattan, followed by Brooklyn and Staten Island.***
#
# * ***Lowest unit cost is in Bronx.***
#
# * ***Because all of NYC's tourist attractions are concentrated in Manhattan and Brooklyn, travellers prefer to stay in these areas, allowing owners to charge greater costs as a result.***
#
# * ***Airbnb should consider investing in any of these two neighbourhood organisations.***

# %% [markdown]
# ##**What are the top ten neighbourhoods in terms of unit count ?**

# %%
# Create the figure and axis objects

plt.figure(figsize=(15, 6))
ax = df['neigh'].value_counts().head(10).plot(kind = 'bar', color='skyblue', edgecolor='black')

# To annotate the countplot.

for p in ax.patches:
  ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()),
  ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

plt.xlabel('Neighbourhood', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Top ten neighbourhoods in terms of unit count', fontsize=16, fontweight = 'bold')
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %% [markdown]
# * ***Williamsburg has the highest number of Airbnb units, followed by Bedford and Harlem.***

# %% [markdown]
# ##**What are the top ten most affordable neighbourhoods ?**

# %%
# Creating a dataframe using groupby.

c = pd.DataFrame(df.groupby('neigh')['price'].mean().sort_values(ascending = True).head(10).reset_index())
c
# Out:
#             neigh      price
# 0     Bull's Head  47.333333
# 1     Hunts Point  50.500000
# 2         Tremont  51.545455
# 3       Soundview  53.466667
# 4        New Dorp  57.000000
# 5       Bronxdale  57.105263
# 6  New Dorp Beach  57.400000
# 7      Grant City  57.666667
# 8         Concord  58.192308
# 9      Mount Eden  58.500000

# %% [markdown]
# * ***Filtering out the top 10 cheap neighbourhoods using group and mean in a dataframe.***

# %%
# Plotting a barplot using the above created dataframe.

plt.figure(figsize = (15,6))
ax = sns.barplot(x = 'neigh', y = 'price', data = c, palette = 'viridis')

# To annotate the countplot.

for p in ax.patches:
  ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()),
  ha='center', va='bottom', fontsize=12, fontweight = 'bold',color='black')


plt.title('Top - ten most affordable neighbourhoods', fontsize = 16, fontweight = 'bold')
plt.xlabel('Neighbourhood', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %% [markdown]
# * ***Among the top 10 cheap neighbourhood Airbnb units, Bull's Head, Hunt's Point, and Tremont units are the cheapest.***

# %% [markdown]
# ##**What are the top ten most expensive neighbourhoods ?**

# %%
# Creating a dataframe using groupby.

e = pd.DataFrame(df.groupby('neigh')['price'].mean().sort_values(ascending = False).head(10).reset_index())
e
# Out:
#                neigh       price
# 0     Fort Wadsworth  800.000000
# 1            Woodrow  700.000000
# 2            Tribeca  490.638418
# 3           Sea Gate  487.857143
# 4          Riverdale  442.090909
# 5       Prince's Bay  409.500000
# 6  Battery Park City  367.557143
# 7  Flatiron District  341.925000
# 8      Randall Manor  336.000000
# 9               NoHo  295.717949

# %% [markdown]
# * ***Filtering out the top 10 expensive neighbourhoods using group and mean in a dataframe.***

# %%
# Plotting a barplot using the above created dataframe.

plt.figure(figsize = (15,6))
ax = sns.barplot(x = 'neigh', y = 'price', data = e, palette = 'viridis')

# To annotate the countplot.

for p in ax.patches:
  ax.annotate(f"{p.get_height():.2f}", (p.get_x() + p.get_width() / 2, p.get_height()),
  ha='center', va='bottom', fontsize=12, fontweight = 'bold',color='black')


plt.title('Top - ten most expensive neighbourhoods', fontsize = 16, fontweight = 'bold')
plt.xlabel('Neighbourhood', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %% [markdown]
# * ***Among the top 10 most expensive neighbourhood Airbnb units, Fort Wadsworth units are the most expensive, followed by Woodrow.***
